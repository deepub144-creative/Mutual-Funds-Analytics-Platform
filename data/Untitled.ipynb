# %%
import pandas as pd
import sqlite3
from pathlib import Path
import os

# ---------- Print current working directory for debugging ----------
print("Current working directory:", os.getcwd())

# ---------- Configuration ----------
# Use absolute path based on the script's location
BASE_DIR = Path(__file__).parent.parent   # goes up one level from scripts/
RAW_DIR = BASE_DIR / "data" / "raw"
PROCESSED_DIR = BASE_DIR / "data" / "processed"
DB_PATH = BASE_DIR / "data" / "db" / "bluestock_mf.db"

print("Looking for files in:", RAW_DIR)

PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
DB_PATH.parent.mkdir(parents=True, exist_ok=True)

# ---------- Map your actual file names to table names ----------
files = {
    "fund_master": "01_fund_master.csv",
    "nav_history": "02_nav_history.csv",
    "aum_by_fund_house": "03_aum_by_fund_house.csv",
    "monthly_sip_inflows": "04_monthly_sip_inflows.csv",
    "category_inflows": "05_category_inflows.csv",
    "industry_folio_count": "06_industry_folio_count.csv",
    "scheme_performance": "07_scheme_performance.csv",
    "investor_transactions": "08_investor_transactions.csv",
    "portfolio_holdings": "09_portfolio_holdings.csv",
    "benchmark_indices": "10_benchmark_indices.csv",
}

dataframes = {}

for name, fname in files.items():
    path = RAW_DIR / fname
    print(f"Checking {path} ... ", end="")
    if path.exists():
        print("✅ found!")
        df = pd.read_csv(path)
        print(f"  -> {df.shape[0]} rows, {df.shape[1]} columns")
        dataframes[name] = df
    else:
        print("❌ NOT FOUND")

# ---------- Basic Cleaning (same as before) ----------
# (I'll include the cleaning code from the previous version – I'll paste it fully below)
# Out:
# Current working directory: C:\Users\deepu\OneDrive\Desktop\bluestock_mf_capstone\data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7 print("Current working directory:", os.getcwd())
#       9 # ---------- Configuration ----------
#      10 # Use absolute path based on the script's location
# ---> 11 BASE_DIR = Path(__file__).parent.parent   # goes up one level from scripts/
#      12 RAW_DIR = BASE_DIR / "data" / "raw"
#      13 PROCESSED_DIR = BASE_DIR / "data" / "processed"
#
# NameError: name '__file__' is not defined
